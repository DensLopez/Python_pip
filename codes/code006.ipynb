# %% [markdown]
# # Flujo de trabajo en Python

# %% [markdown]
# Es momento de empezar a crear y correr proyectos más complejos con este flujo de trabajo.
#
# Vamos a correr el juego de piedra papel o tijera para implementarlo y ejecutarlo.

# %% [markdown]
# ## Implementando aplicación
# Estando en la carpeta "[py-project](py-project)" creamos una carpeta llamada "[game](py-project/game/)" y allí dentro ponemos el código del juego, lo llamamos "[main.py](py-project/game/main.py)".
#
# Una vez que hemos creado la carpeta y el código, procederemos a correrlo a traves de la terminal.
#
# Estando en la terminal corremos la siguientes lineas de comando:
#
# ```bash
# cd py-project/game/     #Cambiar a directorio del juego
#
# python3 main.py     #Ejecutar el archivo del juego
# ```
#
# Aquí tenemos nuestro juego corriendo desde nuestra computadora.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora que he ejecutado el código, vamos a agregar el archivo al repositorio de git hub con los siguientes comandos:
#
# ```bash
# git add --all
# git commit -m "Agregando archivo de ejemplo"
# git pul origin main
# git push origin main
# ```
#
# Aquí ya hemos subido las actualizaciones del juego a nuestro repositorio de Git Hub.

# %% [markdown]
# ## Modificación de README.md

# %% [markdown]
# Una vez que hemos creado el despliegue de la app, tenemos que crear el archivo de instrucciones, para que las personas lo puedan desplegar.
#
# [README.md](py-project/game/README.md)

# %% [markdown]
# Después procedemos a realizar el commit para subirlo al repositorio de Git Hub. Corramos los siguientes comandos de Git:
#
# ```sh
# git add --all
# git commit -m "Añadiendo README.md"
# git pull origin main
# git push origin main
# ```
#
# Listo ya tenemos nuestro juego implementado en nuestro repositorio.
#
# [Ir a carpeta del juego](py-project/game/)
